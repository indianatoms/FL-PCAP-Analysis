# %%
import matplotlib.pyplot as plt

# %%
y1 = [
 0.7812592778678603 
, 0.7517810938219969
, 0.7513680589798791 
, 0.7995343809761369 
, 0.8260584420316257 
, 0.8226911121647963 
, 0.8248348461249262 
, 0.8188808986404914 
, 0.8211545054191609 
, 0.8311545054191609 
, 0.8301994550697034 
]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds", fontsize=16)
plt.ylabel("F1-Score", fontsize=16)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.title('UNSW (Non-IID) - SGD-LR E=1, R=10, B=0.8, C=5')
plt.show()

# %%
y1 = [
0.6983473896267969 
,0.8172956320827375 
,0.754749092129391 
,0.7876770942283922 
,0.8278581972811598 
,0.8224178131523371 
,0.7955164334114367 
,0.8207740377041433 
,0.8207306936179758 
,0.843279166097683 
, 0.8446977089106592 
 ]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds", fontsize=16)
plt.ylabel("F1-Score", fontsize=16)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.title('UNSW (Non-IID) - SGD-LR E=5, R=10, B=0.8, C=5')
plt.show()

# %%
y1 = [
0.8204939341421145
,0.7820154899135445
,0.7937480552430647
,0.8306514989500264
,0.8164132744809547 
,0.8353053477479078 
,0.8124992015534576 
,0.8254035366975898 
,0.8426875121427184
,0.8155028399599066 
 ]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds", fontsize=16)
plt.ylabel("F1-Score", fontsize=16)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.title('UNSW (Non-IID)  - SGD-LR E=10 R=10, B=0.8, C=5')
plt.show()

# %%
y1 = [
0.6967854039965248
,0.7742460167462746
,0.7452664362310806
,0.7859549773014461
,0.7739472436808997
,0.7849816894382734
,0.8277785646579431
,0.828367953824714
,0.8180526718391432
,0.8174989794529868
,0.839558141405475 ]


plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds", fontsize=16)
plt.ylabel("F1-Score", fontsize=16)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.title('UNSW (Non-IID)  - SGD-LR E=10, R=10, B=0.9 C=5')
plt.show()

# %%
y1 = [
0.7606711031961759
,0.801634591238043
,0.8121440338903272
,0.8255929742894506
,0.8385938984482213
,0.8594053738178437
,0.8597139338827319
,0.8203841776415115
,0.8580380212949209
,0.8552603344903755 
]


plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds", fontsize=16)
plt.ylabel("F1-Score", fontsize=16)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.title('UNSW (Non-IID)  - SGD-LR E=20, R=10, B=0.8 C=5')
plt.show()
