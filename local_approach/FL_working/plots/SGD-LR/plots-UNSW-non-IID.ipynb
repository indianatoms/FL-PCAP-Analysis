# %%
import matplotlib.pyplot as plt

# %%
y1 = [
 0.7812592778678603 
, 0.7517810938219969
, 0.7513680589798791 
, 0.7995343809761369 
, 0.8260584420316257 
, 0.8226911121647963 
, 0.8248348461249262 
, 0.8188808986404914 
, 0.8211545054191609 
, 0.8201994550697034 
, 0.8286964221990193 
, 0.8188205674943161 
, 0.8128310156800334 
, 0.8280298458331048 
, 0.8427604942830391 
, 0.8319927313540526 
, 0.8532638838650558 
, 0.8321662219453061 
, 0.8380767989674087 
, 0.8289553389503829 
, 0.8300719206809775 
, 0.8293933896247391 
, 0.8510947416715521 
, 0.8304640972420062 
, 0.849701768819416 
, 0.8291577352101908 
, 0.8543694274015586 
, 0.8318387472569153 
, 0.8539277322664635 ]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds")
plt.ylabel("F1-Score")
plt.title('UNSW (Non-IID) - SGD-LR E=5, R=10, B=0.8, C=5')
plt.show()

# %%
y1 = [
0.6983473896267969 
,0.8172956320827375 
,0.754749092129391 
,0.7876770942283922 
,0.8278581972811598 
,0.8224178131523371 
,0.7955164334114367 
,0.8207740377041433 
,0.8207306936179758 
,0.843279166097683 
, 0.8446977089106592 
 ]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds")
plt.ylabel("F1-Score")
plt.title('UNSW (Non-IID) - SGD-LR E=5, R=10, B=0.8, C=5')
plt.show()

# %%
y1 = [
0.8204939341421145
,0.7820154899135445
,0.7937480552430647
,0.8306514989500264
,0.8164132744809547 
,0.8353053477479078 
,0.8124992015534576 
,0.8254035366975898 
,0.8426875121427184
,0.8155028399599066 
 ]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds")
plt.ylabel("F1-Score")
plt.title('UNSW (Non-IID)  - SGD-LR E=10 R=10, B=0.8, C=5')
plt.show()

# %%
y1 = [
0.6967854039965248
,0.7742460167462746
,0.7452664362310806
,0.7859549773014461
,0.7739472436808997
,0.7849816894382734
,0.8277785646579431
,0.828367953824714
,0.8180526718391432
,0.8174989794529868
,0.839558141405475 ]


plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds")
plt.ylabel("F1-Score")
plt.title('UNSW (Non-IID)  - SGD-LR E=10, R=10, B=0.9 C=5')
plt.show()

# %%
y1 = [
0.696160423348846,
0.7076545413970096,
0.7623858602296356,
0.7784304374629244,
0.785338565584036, 
0.8325230732087398,
0.771797124702347,
0.8106471107489645,
0.8354977877326744,
0.8197907966432009,
0.8450331125827816
]


plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds")
plt.ylabel("F1-Score")
plt.title('UNSW (Non-IID)  - SGD-LR E=20, R=10, B=0.9 C=5')
plt.show()
