# %%
import os
import sys
module_path = os.path.abspath(os.path.join('fede'))
if module_path not in sys.path:
    sys.path.append(module_path)

from client import Client
from sklearn.linear_model import (
    LogisticRegression,
    SGDClassifier,
    RidgeClassifier,
) 
from sklearn.model_selection import GridSearchCV

# %%
client1 = Client("node1","local_host",)
dataset1 = client1.load_data('../../datasets/MachineLearningCSV/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv', True)
client1.preprocess_data(dataset1, True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/tk/Desktop/Studia/masters/git-repo/local_approach/FL_working/gridsearch.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/tk/Desktop/Studia/masters/git-repo/local_approach/FL_working/gridsearch.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> client1 = Client("node1")
#       <a href='vscode-notebook-cell:/home/tk/Desktop/Studia/masters/git-repo/local_approach/FL_working/gridsearch.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> dataset1 = client1.load_data('../../datasets/MachineLearningCSV/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv', True)
#       <a href='vscode-notebook-cell:/home/tk/Desktop/Studia/masters/git-repo/local_approach/FL_working/gridsearch.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> client1.preprocess_data(dataset1, True)
#
# ...

# %%
params = {
    "loss" : ["hinge", "log", "squared_hinge", "modified_huber", "perceptron"],
    "alpha" : [0.0001, 0.001, 0.01, 0.1],
    "penalty" : ["l2", "l1", "elasticnet", "none"],
}

clf = SGDClassifier(max_iter=1000)
grid = GridSearchCV(clf, param_grid=params, cv=10)


grid.fit(client1.x, client1.y)

print(grid.best_params_)
# Out:
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:696: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/tk/Desktop/Studia/masters/git-repo/local_approach/FL_working/gridsearch.ipynb Cell 3 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/home/tk/Desktop/Studia/masters/git-repo/local_approach/FL_working/gridsearch.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> clf = SGDClassifier(max_iter=1000)
#       <a href='vscode-notebook-cell:/home/tk/Desktop/Studia/masters/git-repo/local_approach/FL_working/gridsearch.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> grid = GridSearchCV(clf, param_grid=params, cv=10)
# ...
