# %%
import os
import sys
module_path = os.path.abspath(os.path.join('fede'))
if module_path not in sys.path:
    sys.path.append(module_path)
from client import Client
from network import Net2nn
from supported_modles import Supported_modles
from sklearn.linear_model import (
    LogisticRegression,
    SGDClassifier,
)
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
selected_model = Supported_modles.SGD_classifier
client1 = Client("node1","0.0.0.0", 5001, selected_model)
dataset = client1.load_data('data/Wednesday-workingHours.pcap_ISCX.csv', True)
# Out:
# Creating node1.

# %% [markdown]
# # CIC

# %%
client1.preprocess_data(dataset, True)
client1.prep_data()

# %%
X_train = client1.x
y_train = client1.y

# %%
params={"C":np.logspace(-3,7,11), "penalty":["l1","l2"]}# l1 lasso l2 ridge
logreg=LogisticRegression()


grid_search = GridSearchCV(logreg, params, cv=5, verbose=10, n_jobs=-1, scoring='f1_micro')

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 22 candidates, totalling 110 fits
# [CV 2/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 1/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 3/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 1/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 4/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 5/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 2/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   0.5s
# [CV 2/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 4/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 3/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 1/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 3/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   1.8s
# [CV 4/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   1.8s
# [CV 1/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 2/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 5/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   2.1s
# [CV 3/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 2/5; 3/22] END ............C=0.01, penalty=l1;, score=nan total time=   1.8s
# [CV 4/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 1/5; 3/22] END ............C=0.01, penalty=l1;, score=nan total time=   2.0s
# [CV 5/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 3/5; 3/22] END ............C=0.01, penalty=l1;, score=nan total time=   1.7s
# [CV 1/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 2/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 3/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 4/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 5/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 1/5; 5/22] START C=0.1, penalty=l1..........................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/tk/Desktop/Studia/masters/git-repo/local_approach/FL_working/centrailized_model.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/tk/Desktop/Studia/masters/git-repo/local_approach/FL_working/centrailized_model.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> grid_search.fit(X_train,y_train)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/anaconda3/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.9722667207957889
# {'C': 100000.0, 'penalty': 'l2'}

# %% [markdown]
# # UNSW

# %%
dataset = client1.load_data('data/UNSW_NB15_train-set.csv')

# %%
dataset1 = client1.load_data('data/UNSW_NB15_test-set.csv')

# %%
dataset
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.121478   tcp       -   FIN      6      4     258     172
# 1            2  0.649902   tcp       -   FIN     14     38     734   42014
# 2            3  1.623129   tcp       -   FIN      8     16     364   13186
# 3            4  1.681642   tcp     ftp   FIN     12     12     628     770
# 4            5  0.449454   tcp       -   FIN     10      6     534     268
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 175336  175337  0.000009   udp     dns   INT      2      0     114       0
# 175337  175338  0.505762   tcp       -   FIN     10      8     620     354
# 175338  175339  0.000009   udp     dns   INT      2      0     114       0
# 175339  175340  0.000009   udp     dns   INT      2      0     114       0
# 175340  175341  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0           74.087490  ...                 1               1             0
# 1           78.473372  ...                 1               2             0
# 2           14.170161  ...                 1               3             0
# 3           13.677108  ...                 1               3             1
# 4           33.373826  ...                 1              40             0
# ...               ...  ...               ...             ...           ...
# 175336  111111.107200  ...                13              24             0
# 175337      33.612649  ...                 1               2             0
# 175338  111111.107200  ...                 3              13             0
# 175339  111111.107200  ...                14              30             0
# 175340  111111.107200  ...                16              30             0
#
#         ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0                0                 0           1           1                0
# 1                0                 0           1           6                0
# 2                0                 0           2           6                0
# 3                1                 0           2           1                0
# 4                0                 0           2          39                0
# ...            ...               ...         ...         ...              ...
# 175336           0                 0          24          24                0
# 175337           0                 0           1           1                0
# 175338           0                 0           3          12                0
# 175339           0                 0          30          30                0
# 175340           0                 0          30          30                0
#
#         attack_cat  label
# 0           Normal      0
# 1           Normal      0
# 2           Normal      0
# 3           Normal      0
# 4           Normal      0
# ...            ...    ...
# 175336     Generic      1
# 175337   Shellcode      1
# 175338     Generic      1
# 175339     Generic      1
# 175340     Generic      1
#
# [175341 rows x 45 columns]

# %%
dataset1
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0          1  0.000011   udp       -   INT      2      0     496       0
# 1          2  0.000008   udp       -   INT      2      0    1762       0
# 2          3  0.000005   udp       -   INT      2      0    1068       0
# 3          4  0.000006   udp       -   INT      2      0     900       0
# 4          5  0.000010   udp       -   INT      2      0    2126       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 82327  82328  0.000005   udp       -   INT      2      0     104       0
# 82328  82329  1.106101   tcp       -   FIN     20      8   18062     354
# 82329  82330  0.000000   arp       -   INT      1      0      46       0
# 82330  82331  0.000000   arp       -   INT      1      0      46       0
# 82331  82332  0.000009   udp       -   INT      2      0     104       0
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0       90909.090200  ...                 1               2             0
# 1      125000.000300  ...                 1               2             0
# 2      200000.005100  ...                 1               3             0
# 3      166666.660800  ...                 1               3             0
# 4      100000.002500  ...                 1               3             0
# ...              ...  ...               ...             ...           ...
# 82327  200000.005100  ...                 1               2             0
# 82328      24.410067  ...                 1               1             0
# 82329       0.000000  ...                 1               1             0
# 82330       0.000000  ...                 1               1             0
# 82331  111111.107200  ...                 1               1             0
#
#        ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0               0                 0           1           2                0
# 1               0                 0           1           2                0
# 2               0                 0           1           3                0
# 3               0                 0           2           3                0
# 4               0                 0           2           3                0
# ...           ...               ...         ...         ...              ...
# 82327           0                 0           2           1                0
# 82328           0                 0           3           2                0
# 82329           0                 0           1           1                1
# 82330           0                 0           1           1                1
# 82331           0                 0           1           1                0
#
#        attack_cat  label
# 0          Normal      0
# 1          Normal      0
# 2          Normal      0
# 3          Normal      0
# 4          Normal      0
# ...           ...    ...
# 82327      Normal      0
# 82328      Normal      0
# 82329      Normal      0
# 82330      Normal      0
# 82331      Normal      0
#
# [82332 rows x 45 columns]

# %%
import pandas as pd

# %%
df = pd.concat([dataset1,dataset], ignore_index=True)

# %%
df
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.000011   udp       -   INT      2      0     496       0
# 1            2  0.000008   udp       -   INT      2      0    1762       0
# 2            3  0.000005   udp       -   INT      2      0    1068       0
# 3            4  0.000006   udp       -   INT      2      0     900       0
# 4            5  0.000010   udp       -   INT      2      0    2126       0
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 257668  175337  0.000009   udp     dns   INT      2      0     114       0
# 257669  175338  0.505762   tcp       -   FIN     10      8     620     354
# 257670  175339  0.000009   udp     dns   INT      2      0     114       0
# 257671  175340  0.000009   udp     dns   INT      2      0     114       0
# 257672  175341  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0        90909.090200  ...                 1               2             0
# 1       125000.000300  ...                 1               2             0
# 2       200000.005100  ...                 1               3             0
# 3       166666.660800  ...                 1               3             0
# 4       100000.002500  ...                 1               3             0
# ...               ...  ...               ...             ...           ...
# 257668  111111.107200  ...                13              24             0
# 257669      33.612649  ...                 1               2             0
# 257670  111111.107200  ...                 3              13             0
# 257671  111111.107200  ...                14              30             0
# 257672  111111.107200  ...                16              30             0
#
#         ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0                0                 0           1           2                0
# 1                0                 0           1           2                0
# 2                0                 0           1           3                0
# 3                0                 0           2           3                0
# 4                0                 0           2           3                0
# ...            ...               ...         ...         ...              ...
# 257668           0                 0          24          24                0
# 257669           0                 0           1           1                0
# 257670           0                 0           3          12                0
# 257671           0                 0          30          30                0
# 257672           0                 0          30          30                0
#
#         attack_cat  label
# 0           Normal      0
# 1           Normal      0
# 2           Normal      0
# 3           Normal      0
# 4           Normal      0
# ...            ...    ...
# 257668     Generic      1
# 257669   Shellcode      1
# 257670     Generic      1
# 257671     Generic      1
# 257672     Generic      1
#
# [257673 rows x 45 columns]

# %%
client1.preprocess_data(df, False)
client1.prep_data()

# %%
X_train = client1.x
y_train = client1.y

# %%
params={"C":np.logspace(-3,7,11), "penalty":["l1","l2"]}# l1 lasso l2 ridge
logreg=LogisticRegression()

grid_search = GridSearchCV(logreg, params, cv=5, verbose=10, n_jobs=-1, scoring='f1_micro')

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 22 candidates, totalling 110 fits
# [CV 1/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 2/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 3/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 4/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 5/5; 1/22] START C=0.001, penalty=l1........................................
# [CV 1/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 2/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 3/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 1/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   0.2s
# [CV 3/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   0.1s
# [CV 5/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 4/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   0.2s
# [CV 4/5; 2/22] START C=0.001, penalty=l2........................................
# [CV 1/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 2/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   0.2s
# [CV 5/5; 1/22] END ...........C=0.001, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 3/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 1/5; 3/22] END ............C=0.01, penalty=l1;, score=nan total time=   0.2s
# [CV 4/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 3/5; 3/22] END ............C=0.01, penalty=l1;, score=nan total time=   0.2s
# [CV 5/5; 3/22] START C=0.01, penalty=l1.........................................
# [CV 2/5; 3/22] END ............C=0.01, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 4/5; 3/22] END ............C=0.01, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 5/5; 3/22] END ............C=0.01, penalty=l1;, score=nan total time=   0.3s
# [CV 3/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 5/5; 2/22] END .........C=0.001, penalty=l2;, score=0.802 total time=   4.2s
# [CV 4/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 2/5; 2/22] END .........C=0.001, penalty=l2;, score=0.702 total time=   4.5s
# [CV 5/5; 4/22] START C=0.01, penalty=l2.........................................
# [CV 1/5; 2/22] END .........C=0.001, penalty=l2;, score=0.965 total time=   5.3s
# [CV 1/5; 5/22] START C=0.1, penalty=l1..........................................
# [CV 4/5; 2/22] END .........C=0.001, penalty=l2;, score=0.980 total time=   5.3s
# [CV 2/5; 5/22] START C=0.1, penalty=l1..........................................
# [CV 1/5; 5/22] END .............C=0.1, penalty=l1;, score=nan total time=   0.2s
# [CV 3/5; 2/22] END .........C=0.001, penalty=l2;, score=0.945 total time=   5.6s
# [CV 4/5; 5/22] START C=0.1, penalty=l1..........................................[CV 3/5; 5/22] START C=0.1, penalty=l1..........................................
#
# [CV 2/5; 5/22] END .............C=0.1, penalty=l1;, score=nan total time=   0.2s
# [CV 5/5; 5/22] START C=0.1, penalty=l1..........................................
# [CV 3/5; 5/22] END .............C=0.1, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 6/22] START C=0.1, penalty=l2..........................................
# [CV 5/5; 5/22] END .............C=0.1, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 6/22] START C=0.1, penalty=l2..........................................
# [CV 4/5; 5/22] END .............C=0.1, penalty=l1;, score=nan total time=   0.3s
# [CV 3/5; 6/22] START C=0.1, penalty=l2..........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 4/22] END ..........C=0.01, penalty=l2;, score=0.713 total time=   9.8s
# [CV 4/5; 6/22] START C=0.1, penalty=l2..........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 4/22] END ..........C=0.01, penalty=l2;, score=0.963 total time=  10.5s
# [CV 5/5; 6/22] START C=0.1, penalty=l2..........................................
# [CV 3/5; 4/22] END ..........C=0.01, penalty=l2;, score=0.938 total time=  10.5s
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 7/22] START C=1.0, penalty=l1..........................................
# [CV 1/5; 7/22] END .............C=1.0, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 7/22] START C=1.0, penalty=l1..........................................
# [CV 2/5; 7/22] END .............C=1.0, penalty=l1;, score=nan total time=   0.2s
# [CV 3/5; 7/22] START C=1.0, penalty=l1..........................................
# [CV 3/5; 7/22] END .............C=1.0, penalty=l1;, score=nan total time=   0.2s
# [CV 4/5; 7/22] START C=1.0, penalty=l1..........................................
# [CV 4/5; 7/22] END .............C=1.0, penalty=l1;, score=nan total time=   0.2s
# [CV 5/5; 7/22] START C=1.0, penalty=l1..........................................
# [CV 5/5; 7/22] END .............C=1.0, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 8/22] START C=1.0, penalty=l2..........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 4/22] END ..........C=0.01, penalty=l2;, score=0.811 total time=   9.0s
# [CV 2/5; 8/22] START C=1.0, penalty=l2..........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 4/22] END ..........C=0.01, penalty=l2;, score=0.977 total time=   9.8s
# [CV 3/5; 8/22] START C=1.0, penalty=l2..........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 6/22] END ...........C=0.1, penalty=l2;, score=0.962 total time=   9.3s
# [CV 4/5; 8/22] START C=1.0, penalty=l2..........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 6/22] END ...........C=0.1, penalty=l2;, score=0.719 total time=  10.0s
# [CV 5/5; 8/22] START C=1.0, penalty=l2..........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 6/22] END ...........C=0.1, penalty=l2;, score=0.937 total time=  10.3s
# [CV 1/5; 9/22] START C=10.0, penalty=l1.........................................
# [CV 1/5; 9/22] END ............C=10.0, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 9/22] START C=10.0, penalty=l1.........................................
# [CV 2/5; 9/22] END ............C=10.0, penalty=l1;, score=nan total time=   0.3s
# [CV 3/5; 9/22] START C=10.0, penalty=l1.........................................
# [CV 3/5; 9/22] END ............C=10.0, penalty=l1;, score=nan total time=   0.2s
# [CV 4/5; 9/22] START C=10.0, penalty=l1.........................................
# [CV 4/5; 9/22] END ............C=10.0, penalty=l1;, score=nan total time=   0.2s
# [CV 5/5; 9/22] START C=10.0, penalty=l1.........................................
# [CV 5/5; 9/22] END ............C=10.0, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 10/22] START C=10.0, penalty=l2........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 6/22] END ...........C=0.1, penalty=l2;, score=0.976 total time=   8.9s
# [CV 2/5; 10/22] START C=10.0, penalty=l2........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 6/22] END ...........C=0.1, penalty=l2;, score=0.816 total time=   9.4s
# [CV 3/5; 10/22] START C=10.0, penalty=l2........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 8/22] END ...........C=1.0, penalty=l2;, score=0.964 total time=   9.1s
# [CV 4/5; 10/22] START C=10.0, penalty=l2........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 8/22] END ...........C=1.0, penalty=l2;, score=0.724 total time=   9.6s
# [CV 5/5; 10/22] START C=10.0, penalty=l2........................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 8/22] END ...........C=1.0, penalty=l2;, score=0.937 total time=   9.3s
# [CV 1/5; 11/22] START C=100.0, penalty=l1.......................................
# [CV 1/5; 11/22] END ..........C=100.0, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 11/22] START C=100.0, penalty=l1.......................................
# [CV 2/5; 11/22] END ..........C=100.0, penalty=l1;, score=nan total time=   0.2s
# [CV 3/5; 11/22] START C=100.0, penalty=l1.......................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 11/22] END ..........C=100.0, penalty=l1;, score=nan total time=   0.2s
# [CV 4/5; 11/22] START C=100.0, penalty=l1.......................................
# [CV 4/5; 8/22] END ...........C=1.0, penalty=l2;, score=0.975 total time=   9.2s
# [CV 5/5; 11/22] START C=100.0, penalty=l1.......................................
# [CV 4/5; 11/22] END ..........C=100.0, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 12/22] START C=100.0, penalty=l2.......................................
# [CV 5/5; 11/22] END ..........C=100.0, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 12/22] START C=100.0, penalty=l2.......................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 8/22] END ...........C=1.0, penalty=l2;, score=0.819 total time=   9.4s
# [CV 3/5; 12/22] START C=100.0, penalty=l2.......................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 10/22] END .........C=10.0, penalty=l2;, score=0.964 total time=   9.5s
# [CV 4/5; 12/22] START C=100.0, penalty=l2.......................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 10/22] END .........C=10.0, penalty=l2;, score=0.729 total time=   8.9s
# [CV 5/5; 12/22] START C=100.0, penalty=l2.......................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 10/22] END .........C=10.0, penalty=l2;, score=0.936 total time=   8.8s
# [CV 1/5; 13/22] START C=1000.0, penalty=l1......................................
# [CV 1/5; 13/22] END .........C=1000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 13/22] START C=1000.0, penalty=l1......................................
# [CV 2/5; 13/22] END .........C=1000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 3/5; 13/22] START C=1000.0, penalty=l1......................................
# [CV 3/5; 13/22] END .........C=1000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 4/5; 13/22] START C=1000.0, penalty=l1......................................
# [CV 4/5; 13/22] END .........C=1000.0, penalty=l1;, score=nan total time=   0.3s
# [CV 5/5; 13/22] START C=1000.0, penalty=l1......................................
# [CV 5/5; 13/22] END .........C=1000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 14/22] START C=1000.0, penalty=l2......................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 10/22] END .........C=10.0, penalty=l2;, score=0.975 total time=   9.7s
# [CV 2/5; 14/22] START C=1000.0, penalty=l2......................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 10/22] END .........C=10.0, penalty=l2;, score=0.820 total time=   8.8s
# [CV 3/5; 14/22] START C=1000.0, penalty=l2......................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 12/22] END ........C=100.0, penalty=l2;, score=0.729 total time=   9.3s
# [CV 4/5; 14/22] START C=1000.0, penalty=l2......................................
# [CV 1/5; 12/22] END ........C=100.0, penalty=l2;, score=0.963 total time=   9.4s
# [CV 5/5; 14/22] START C=1000.0, penalty=l2......................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 12/22] END ........C=100.0, penalty=l2;, score=0.936 total time=   9.2s
# [CV 1/5; 15/22] START C=10000.0, penalty=l1.....................................
# [CV 1/5; 15/22] END ........C=10000.0, penalty=l1;, score=nan total time=   0.3s
# [CV 2/5; 15/22] START C=10000.0, penalty=l1.....................................
# [CV 2/5; 15/22] END ........C=10000.0, penalty=l1;, score=nan total time=   0.3s
# [CV 3/5; 15/22] START C=10000.0, penalty=l1.....................................
# [CV 3/5; 15/22] END ........C=10000.0, penalty=l1;, score=nan total time=   0.3s
# [CV 4/5; 15/22] START C=10000.0, penalty=l1.....................................
# [CV 4/5; 15/22] END ........C=10000.0, penalty=l1;, score=nan total time=   0.3s
# [CV 5/5; 15/22] START C=10000.0, penalty=l1.....................................
# [CV 5/5; 15/22] END ........C=10000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 16/22] START C=10000.0, penalty=l2.....................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 12/22] END ........C=100.0, penalty=l2;, score=0.976 total time=   9.4s
# [CV 2/5; 16/22] START C=10000.0, penalty=l2.....................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 12/22] END ........C=100.0, penalty=l2;, score=0.820 total time=   9.4s
# [CV 3/5; 16/22] START C=10000.0, penalty=l2.....................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 14/22] END .......C=1000.0, penalty=l2;, score=0.964 total time=   9.4s
# [CV 4/5; 16/22] START C=10000.0, penalty=l2.....................................
# [CV 2/5; 14/22] END .......C=1000.0, penalty=l2;, score=0.728 total time=   8.7s
# [CV 5/5; 16/22] START C=10000.0, penalty=l2.....................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 14/22] END .......C=1000.0, penalty=l2;, score=0.937 total time=   9.3s
# [CV 1/5; 17/22] START C=100000.0, penalty=l1....................................
# [CV 1/5; 17/22] END .......C=100000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 17/22] START C=100000.0, penalty=l1....................................
# [CV 2/5; 17/22] END .......C=100000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 3/5; 17/22] START C=100000.0, penalty=l1....................................
# [CV 3/5; 17/22] END .......C=100000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 4/5; 17/22] START C=100000.0, penalty=l1....................................
# [CV 4/5; 17/22] END .......C=100000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 5/5; 17/22] START C=100000.0, penalty=l1....................................
# [CV 5/5; 17/22] END .......C=100000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 18/22] START C=100000.0, penalty=l2....................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 14/22] END .......C=1000.0, penalty=l2;, score=0.821 total time=   9.2s
# [CV 2/5; 18/22] START C=100000.0, penalty=l2....................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 14/22] END .......C=1000.0, penalty=l2;, score=0.976 total time=   9.5s
# [CV 3/5; 18/22] START C=100000.0, penalty=l2....................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 16/22] END ......C=10000.0, penalty=l2;, score=0.962 total time=   9.2s
# [CV 4/5; 18/22] START C=100000.0, penalty=l2....................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 16/22] END ......C=10000.0, penalty=l2;, score=0.729 total time=   9.1s
# [CV 5/5; 18/22] START C=100000.0, penalty=l2....................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 16/22] END ......C=10000.0, penalty=l2;, score=0.937 total time=   9.9s
# [CV 1/5; 19/22] START C=1000000.0, penalty=l1...................................
# [CV 1/5; 19/22] END ......C=1000000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 19/22] START C=1000000.0, penalty=l1...................................
# [CV 2/5; 19/22] END ......C=1000000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 3/5; 19/22] START C=1000000.0, penalty=l1...................................
# [CV 3/5; 19/22] END ......C=1000000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 4/5; 19/22] START C=1000000.0, penalty=l1...................................
# [CV 4/5; 19/22] END ......C=1000000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 5/5; 19/22] START C=1000000.0, penalty=l1...................................
# [CV 5/5; 19/22] END ......C=1000000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 20/22] START C=1000000.0, penalty=l2...................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 16/22] END ......C=10000.0, penalty=l2;, score=0.821 total time=   9.2s
# [CV 2/5; 20/22] START C=1000000.0, penalty=l2...................................
# [CV 4/5; 16/22] END ......C=10000.0, penalty=l2;, score=0.977 total time=   9.5s
# [CV 3/5; 20/22] START C=1000000.0, penalty=l2...................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 18/22] END .....C=100000.0, penalty=l2;, score=0.965 total time=   9.4s
# [CV 4/5; 20/22] START C=1000000.0, penalty=l2...................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 18/22] END .....C=100000.0, penalty=l2;, score=0.729 total time=   9.0s
# [CV 5/5; 20/22] START C=1000000.0, penalty=l2...................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 18/22] END .....C=100000.0, penalty=l2;, score=0.937 total time=   9.6s
# [CV 1/5; 21/22] START C=10000000.0, penalty=l1..................................
# [CV 1/5; 21/22] END .....C=10000000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 2/5; 21/22] START C=10000000.0, penalty=l1..................................
# [CV 2/5; 21/22] END .....C=10000000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 3/5; 21/22] START C=10000000.0, penalty=l1..................................
# [CV 3/5; 21/22] END .....C=10000000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 4/5; 21/22] START C=10000000.0, penalty=l1..................................
# [CV 4/5; 21/22] END .....C=10000000.0, penalty=l1;, score=nan total time=   0.3s
# [CV 5/5; 21/22] START C=10000000.0, penalty=l1..................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 18/22] END .....C=100000.0, penalty=l2;, score=0.822 total time=   8.8s
# [CV 5/5; 21/22] END .....C=10000000.0, penalty=l1;, score=nan total time=   0.2s
# [CV 1/5; 22/22] START C=10000000.0, penalty=l2..................................
# [CV 2/5; 22/22] START C=10000000.0, penalty=l2..................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 18/22] END .....C=100000.0, penalty=l2;, score=0.976 total time=   9.6s
# [CV 3/5; 22/22] START C=10000000.0, penalty=l2..................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 20/22] END ....C=1000000.0, penalty=l2;, score=0.964 total time=   8.8s
# [CV 4/5; 22/22] START C=10000000.0, penalty=l2..................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 20/22] END ....C=1000000.0, penalty=l2;, score=0.728 total time=   9.2s
# [CV 5/5; 22/22] START C=10000000.0, penalty=l2..................................
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 20/22] END ....C=1000000.0, penalty=l2;, score=0.936 total time=   9.4s
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 20/22] END ....C=1000000.0, penalty=l2;, score=0.976 total time=   9.3s
# [CV 5/5; 20/22] END ....C=1000000.0, penalty=l2;, score=0.821 total time=   9.1s
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 22/22] END ...C=10000000.0, penalty=l2;, score=0.965 total time=   8.0s
# [CV 2/5; 22/22] END ...C=10000000.0, penalty=l2;, score=0.729 total time=   8.0s
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 22/22] END ...C=10000000.0, penalty=l2;, score=0.936 total time=   8.1s
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 55 fits failed out of a total of 110.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 55 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/tk/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.87887759        nan 0.88033681        nan 0.88181155
#         nan 0.88355795        nan 0.88489685        nan 0.88466788
#         nan 0.88503268        nan 0.88521897        nan 0.88580498
#         nan 0.88518016        nan 0.88530435]
#   warnings.warn(
# [CV 4/5; 22/22] END ...C=10000000.0, penalty=l2;, score=0.976 total time=   6.3s
# [CV 5/5; 22/22] END ...C=10000000.0, penalty=l2;, score=0.821 total time=   5.8s
# /home/tk/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04,
#        1.e+05, 1.e+06, 1.e+07]),
#                          'penalty': ['l1', 'l2']},
#              scoring='f1_micro', verbose=10)

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.8858049823686395
# {'C': 100000.0, 'penalty': 'l2'}

# %%
import torch
from torch import nn
import torch.nn.functional as F

# %%
from skorch import NeuralNetClassifier
import numpy as np
from sklearn.datasets import make_classification
from torch import nn

X = X_train.astype(np.float32)
y = y_train.astype(np.int64)

class MyModule(nn.Module):
    def __init__(self):
        super(MyModule, self).__init__()
        self.fc1=nn.Linear(78,256)
        self.fc2=nn.Linear(256,64)
        self.fc3=nn.Linear(64,2)
        self.relu = nn.ReLU()
        
    def forward(self,x):
        x=F.relu(self.fc1(x))
        x=F.relu(self.fc2(x))
        x=self.fc3(x)
        return x


net = NeuralNetClassifier(
    MyModule,
    max_epochs=10,
    criterion=nn.CrossEntropyLoss(),
    optimizer=torch.optim.SGD,
    lr=0.1,
    # Shuffle training data on each epoch
    iterator_train__shuffle=True,
)

net.fit(X, y)
y_proba = net.predict_proba(X)
# Out:
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        0.0360       0.9234        1.1868  14.7852
#       2        0.0231       0.9254        1.5965  19.1730
#       3        0.0215       0.9219        1.7454  28.9478
#       4        0.0209       0.9191        1.8270  19.6139
#       5        0.0202       0.9195        1.8777  20.7658
#       6        0.0197       0.9193        2.0835  24.3616
#       7        0.0193       0.9247        2.1236  21.3408
#       8        0.0190       0.9269        2.1713  18.1540
#       9        0.0188       0.9242        2.1845  18.1194
#      10        0.0184       0.9195        2.3387  18.3467

# %%
from sklearn.model_selection import GridSearchCV

# deactivate skorch-internal train-valid split and verbose logging
net.set_params(train_split=False, verbose=0)
params = {
    'lr': [1,0.1],
    'max_epochs': [10],
}
gs = GridSearchCV(net, params, refit=False, cv=3, scoring='accuracy', n_jobs=-1, verbose=10)

gs.fit(X, y)
print(gs.best_score_, gs.best_params_)
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 1/3; 1/2] START lr=1, max_epochs=10.........................................
# [CV 3/3; 2/2] START lr=0.1, max_epochs=10.......................................
# [CV 3/3; 1/2] START lr=1, max_epochs=10.........................................
# [CV 2/3; 1/2] START lr=1, max_epochs=10.........................................
# [CV 2/3; 2/2] START lr=0.1, max_epochs=10.......................................
# [CV 1/3; 2/2] START lr=0.1, max_epochs=10.......................................
# [CV 3/3; 2/2] END ........lr=0.1, max_epochs=10;, score=0.917 total time= 4.5min
# [CV 2/3; 2/2] END ........lr=0.1, max_epochs=10;, score=0.991 total time= 4.5min
# [CV 3/3; 1/2] END ..........lr=1, max_epochs=10;, score=0.941 total time= 4.6min
# [CV 2/3; 1/2] END ..........lr=1, max_epochs=10;, score=0.636 total time= 4.6min
# [CV 1/3; 2/2] END ........lr=0.1, max_epochs=10;, score=0.949 total time= 4.7min
# [CV 1/3; 1/2] END ..........lr=1, max_epochs=10;, score=0.942 total time= 5.4min
# 0.9525386891646409 {'lr': 0.1, 'max_epochs': 10}
