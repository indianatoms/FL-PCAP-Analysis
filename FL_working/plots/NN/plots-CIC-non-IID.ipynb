# %%
import matplotlib.pyplot as plt

# %%
y1 = [
0.8148643811954374
,0.8714563106796116
,0.8608934810079536
,0.8014739461127822
,0.817130755353361 
,0.8634211305119858 
,0.8348662841878396 
,0.8612609426120789
,0.8627972627440548 
,0.8455485120069949 
,0.7851635625218135 
,0.863079854085746
,0.797645374274123
,0.8837093026675685
,0.797297512121453 
,0.797019241463686
,0.8032685833504559
,0.8848053628131248
,0.8144874420610111
,0.8869496579547448
,0.8868990825688073
,0.8862834978843441
,0.8060313554777452
,0.8162937570451352
,0.8072598829966727
,0.8072598829966727
,0.7983066223162987 
,0.797868448262149 
,0.8896935933147632
,0.9123740842490842
,0.8889670123630399 
,0.8902612547857593 
,0.8066853596295013
,0.7994212852554929 
,0.8427655635623691 
,0.8423547400611621
,0.8117410812337235
,0.8173192817628333 
,0.8277238136484564 
,0.8044316601340246
]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds", fontsize=16)
plt.ylabel("F1-Score", fontsize=16)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.title('CICIDS (Non-IID) - SGD-LR E=1 R=40, B=0.9, C=5')
plt.show()

# %%
y1 = [
0.7866799716732119, 
0.8383637199325877,
0.8024766027885656,
0.8656409325405829,
0.8429256771717469,
0.8617979047991223,
0.8139996846917863,
0.8108472873934811,
0.8500402876839058,
0.8629993663518074 
]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds", fontsize=16)
plt.ylabel("F1-Score", fontsize=16)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.title('CICIDS (Non-IID) - SGD-LR E=5 R=10, B=0.9, C=5')
plt.show()

# %%
y1 = [
0.7840677024620563,0.7864908854166668,0.7974273417476668,0.8048510219157843,0.8359733029864976
]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds", fontsize=16)
plt.ylabel("F1-Score", fontsize=16)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.title('CICIDS (Non-IID) - SGD-LR E=10 R=5, B=0.8, C=5')
plt.show()

# %%
y1 = [
0.7840677024620563,0.7864908854166668,0.7974273417476668,0.8048510219157843,0.8359733029864976
]

plt.rcParams["figure.figsize"] = (10,10)
plt.plot(y1)

plt.xlabel("Number of Rounds", fontsize=16)
plt.ylabel("F1-Score", fontsize=16)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.title('CICIDS (Non-IID) - SGD-LR E=20 R=5, B=0.8, C=5')
plt.show()
